# %%
# !unzip '/content/drive/MyDrive/bedsores/dataset.zip'
# Out:
# Archive:  /content/drive/MyDrive/bedsores/dataset.zip
#    creating: dataset/
#    creating: dataset/test/
#    creating: dataset/test/Abrasions/
#   inflating: dataset/test/Abrasions/mirrored_abrasions (54).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (55).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (56).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (57).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (58).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (59).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (60).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (63).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (64).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (65).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (66).jpg
#   inflating: dataset/test/Abrasions/mirrored_abrasions (67).jpg
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
DATA_DIR='/content/dataset'

# %%
# !yolo task=classify mode=train model=yolov8m-cls.pt data='{DATA_DIR}' epochs=30 imgsz=128
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r '/content/runs/train_cls.zip' '/content/runs/classify/train3'
# Out:
#   adding: content/runs/classify/train3/ (stored 0%)
#   adding: content/runs/classify/train3/results.csv (deflated 87%)
#   adding: content/runs/classify/train3/train_batch1.jpg (deflated 3%)
#   adding: content/runs/classify/train3/val_batch0_pred.jpg (deflated 1%)
#   adding: content/runs/classify/train3/weights/ (stored 0%)
#   adding: content/runs/classify/train3/weights/best.pt (deflated 8%)
#   adding: content/runs/classify/train3/weights/last.pt (deflated 8%)
#   adding: content/runs/classify/train3/val_batch2_labels.jpg (deflated 2%)
#   adding: content/runs/classify/train3/train_batch2.jpg (deflated 5%)
#   adding: content/runs/classify/train3/val_batch1_pred.jpg (deflated 1%)
#   adding: content/runs/classify/train3/train_batch0.jpg (deflated 5%)
#   adding: content/runs/classify/train3/train_batch3060.jpg (deflated 3%)
#   adding: content/runs/classify/train3/confusion_matrix_normalized.png (deflated 22%)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
Image(filename=f'{HOME}/runs/classify/train3/confusion_matrix.png')
# Out:
# /content

# %%
Image(filename=f'{HOME}/runs/classify/train3/confusion_matrix_normalized.png')
